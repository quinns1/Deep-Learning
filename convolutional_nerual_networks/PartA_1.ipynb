# %%
# -*- coding: utf-8 -*-
"""
Name: Shane Quinn
Student Number: R00144107
Email: shane.quinn1@mycit.ie
Course: MSc Artificial Intelligence
Module: Deep Learning
Date: 01/05/2021
"""

# from google.colab import drive
# drive.mount('/content/gdrive')

# !unzip "/content/gdrive/My Drive/datasets/earth_data.zip" -d "./"

# !ls

import numpy as np
import h5py
import matplotlib.pyplot as plt
from tensorflow.python.client import device_lib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import functools
import time
import os


def exec_time(func):
    """
    Generic Execution time recorder, pass in function. Records execution time using decorators
    Have used this in previous assignments to record execution time

    Parameters
    ----------
    func : FUNCTION
        Function we're recording and printing execution time of.
    """
    
    @functools.wraps(func)
    def record_exec_time(*args, **kwargs):
        start_time = time.perf_counter()
        mn = func(*args, **kwargs)
        execution_time = time.perf_counter() - start_time
        print("Execution Time: ", execution_time)
        return mn

    return record_exec_time

def part_a_1_baseline():
    """
    1 Convolutional & Pooling layers -> 1 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """
     
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(16, kernel_size=3, activation='relu', padding="same")(input)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1_op)
    flat1_op = keras.layers.Flatten()(pool1_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat1_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)  
    model = keras.Model(inputs=input, outputs=smax_op)
    
    return model




def part_a_1_basic1():
    """
    2 Convolutional & Pooling layers -> 2 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """
    
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(16, kernel_size=3, activation='relu', padding="same")(input)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1_op)
    conv2_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(pool1_op)
    pool2_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2_op)
    flat1_op = keras.layers.Flatten()(pool2_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat1_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)
    model = keras.Model(inputs=input, outputs=smax_op)

    return model


def part_a_1_basic2():
    """
    5 Convolutional & Pooling layers -> 2 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """ 
    
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(16, kernel_size=3, activation='relu', padding="same")(input)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1_op)
    conv2_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(pool1_op)
    pool2_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2_op)    
    conv3_op = keras.layers.Conv2D(64, kernel_size=3, activation='relu', padding="same")(pool2_op)
    pool3_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3_op)
    conv4_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(pool3_op)
    pool4_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv4_op)
    conv5_op = keras.layers.Conv2D(86, kernel_size=3, activation='relu', padding="same")(pool4_op)
    pool5_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv5_op)   
    flat1_op = keras.layers.Flatten()(pool5_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat1_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)
    model = keras.Model(inputs=input, outputs=smax_op)

    return model


def part_a_1_basic3():
    """
    6 Convolutional & Pooling layers -> 1 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """
     
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(16, kernel_size=3, activation='relu', padding="same")(input)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1_op)
    conv2_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(pool1_op)
    pool2_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2_op)    
    conv3_op = keras.layers.Conv2D(64, kernel_size=3, activation='relu', padding="same")(pool2_op)
    pool3_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3_op)
    conv4_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(pool3_op)
    pool4_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv4_op)
    conv5_op = keras.layers.Conv2D(86, kernel_size=3, activation='relu', padding="same")(pool4_op)
    pool5_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv5_op)
    conv6_op = keras.layers.Conv2D(64, kernel_size=3, activation='relu', padding="same")(pool5_op)
    pool6_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv6_op) 
    flat_op = keras.layers.Flatten()(pool6_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)
    model = keras.Model(inputs=input, outputs=smax_op)   

    return model


def part_a_1_basic4():
    """
    6 Convolutional & 3 Pooling layers -> 1 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """
    
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(254, kernel_size=3, activation='relu', padding="same")(input)
    conv2_op = keras.layers.Conv2D(254, kernel_size=3, activation='relu', padding="same")(conv1_op)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2_op)    
    conv3_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(pool1_op)
    conv4_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(conv3_op)
    pool2_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv4_op)
    conv5_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(pool2_op)
    conv6_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(conv5_op)
    pool3_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv6_op)  
    flat_op = keras.layers.Flatten()(pool3_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)
    model = keras.Model(inputs=input, outputs=smax_op)

    return model

def part_a_1_basic5():
    """
    5 Convolutional & 4 Pooling layers -> 1 Densely Connected layers -> SoftMax layer

    Returns
    -------
    model : Model object
        Model described above.

    """
      
    input = keras.Input(shape=(64,64,3))
    conv1_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(input)
    pool1_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1_op)
    conv2_op = keras.layers.Conv2D(128, kernel_size=3, activation='relu', padding="same")(pool1_op)
    pool2_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2_op)    
    conv3_op = keras.layers.Conv2D(64, kernel_size=3, activation='relu', padding="same")(pool2_op)
    conv4_op = keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding="same")(conv3_op)
    pool3_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv4_op)
    conv5_op = keras.layers.Conv2D(16, kernel_size=3, activation='relu', padding="same")(pool3_op)
    pool4_op = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv5_op)    
    flat_op = keras.layers.Flatten()(pool4_op)
    dense_op = keras.layers.Dense(512, activation='relu')(flat_op)
    smax_op = keras.layers.Dense(9, activation=tf.nn.softmax)(dense_op)
    model = keras.Model(inputs=input, outputs=smax_op)

    return model
    

def part_a_1_data_augmentation(X, y):
    """
    Take in training data and target class labels and return image generator object

    Parameters
    ----------
    X : Numpy Array
        Training data.
    y : Numpy Array
        Training target classes.
        
    Returns
    -------
    train_generator : Training generator object
        Feed data augmentated images to NN.

    """
    
    train_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(shear_range=0.1,
                                                                     zoom_range=0.3,
                                                                     rotation_range=20,
                                                                     horizontal_flip=True, 
                                                                     vertical_flip=True)
    
    train_generator = train_data_gen.flow(X, y, batch_size = 32)
    
    return train_generator
    
    


@exec_time 
def main():
    """
    Create 6 different neural network architectures and compare. See report for more details on architectures

    Returns
    -------
    None.

    """
    
    X, y, X_val, y_val = loadDataH5()
    
    'Uncomment model to create'
    # model = part_a_1_baseline()
    # model = part_a_1_basic1()
    # model = part_a_1_basic2()
    # model = part_a_1_basic3()
    # model = part_a_1_basic4()
    model = part_a_1_basic5()

    image_gen = part_a_1_data_augmentation(X, y)    
    NUM_EPOCHS= 20    
    model.compile(optimizer='adam', 
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(image_gen, epochs=NUM_EPOCHS,  validation_data=(X_val, y_val))

    plt.style.use("ggplot")
    plt.figure()
    plt.axis([0, NUM_EPOCHS, 0, 1])
    plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
    plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
    plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
    plt.title("Training Loss and Accuracy")
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend(loc='lower left')
    plt.show()
    
    
    

    
def loadDataH5():
    """
    

    Returns
    -------
    trainX : NUMPY ARRAY
        Training data.
    trainY : NUMPY ARRAY
        Training target class values.
    valX : NUMPY ARRAY
        Test data.
    valY : NUMPY ARRAY
        Test target class values.

    """
    with h5py.File('earth_data.h5','r') as hf:
        trainX = np.array(hf.get('trainX'))
        trainY = np.array(hf.get('trainY'))
        valX = np.array(hf.get('valX'))
        valY = np.array(hf.get('valY'))
    return trainX, trainY, valX, valY


if __name__=="__main__":
    main()
# Out:
# Epoch 1/100
# 600/600 [==============================] - 25s 41ms/step - loss: 1.9480 - accuracy: 0.3474 - val_loss: 1.1215 - val_accuracy: 0.5844
# Epoch 2/100
# 600/600 [==============================] - 24s 40ms/step - loss: 1.0725 - accuracy: 0.6068 - val_loss: 0.8672 - val_accuracy: 0.6792
# Epoch 3/100
# 600/600 [==============================] - 24s 40ms/step - loss: 0.9415 - accuracy: 0.6558 - val_loss: 0.9818 - val_accuracy: 0.6596
# Epoch 4/100
# 600/600 [==============================] - 24s 40ms/step - loss: 0.8698 - accuracy: 0.6753 - val_loss: 1.0048 - val_accuracy: 0.6498
# Epoch 5/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.8189 - accuracy: 0.6991 - val_loss: 0.8074 - val_accuracy: 0.7123
# Epoch 6/100
# 600/600 [==============================] - 26s 43ms/step - loss: 0.7610 - accuracy: 0.7210 - val_loss: 0.9449 - val_accuracy: 0.6694
# Epoch 7/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.7133 - accuracy: 0.7391 - val_loss: 0.6159 - val_accuracy: 0.7756
# Epoch 8/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.6550 - accuracy: 0.7673 - val_loss: 0.6386 - val_accuracy: 0.7835
# Epoch 9/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.6261 - accuracy: 0.7800 - val_loss: 0.6599 - val_accuracy: 0.7746
# Epoch 10/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.6070 - accuracy: 0.7852 - val_loss: 0.6790 - val_accuracy: 0.7617
# Epoch 11/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.5540 - accuracy: 0.8043 - val_loss: 0.5024 - val_accuracy: 0.8242
# Epoch 12/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.5596 - accuracy: 0.8039 - val_loss: 0.5797 - val_accuracy: 0.7967
# Epoch 13/100
# 600/600 [==============================] - 24s 41ms/step - loss: 0.5148 - accuracy: 0.8159 - val_loss: 0.6381 - val_accuracy: 0.7817
# Epoch 14/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.5040 - accuracy: 0.8222 - val_loss: 0.4804 - val_accuracy: 0.8271
# Epoch 15/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4943 - accuracy: 0.8271 - val_loss: 0.4481 - val_accuracy: 0.8460
# Epoch 16/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4686 - accuracy: 0.8354 - val_loss: 0.4758 - val_accuracy: 0.8342
# Epoch 17/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4634 - accuracy: 0.8376 - val_loss: 0.6215 - val_accuracy: 0.7977
# Epoch 18/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4509 - accuracy: 0.8359 - val_loss: 0.4411 - val_accuracy: 0.8527
# Epoch 19/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4233 - accuracy: 0.8527 - val_loss: 0.5731 - val_accuracy: 0.8129
# Epoch 20/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4323 - accuracy: 0.8476 - val_loss: 0.4986 - val_accuracy: 0.8200
# Epoch 21/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4153 - accuracy: 0.8508 - val_loss: 0.4291 - val_accuracy: 0.8537
# Epoch 22/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4144 - accuracy: 0.8540 - val_loss: 0.5532 - val_accuracy: 0.8194
# Epoch 23/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3974 - accuracy: 0.8623 - val_loss: 0.4443 - val_accuracy: 0.8477
# Epoch 24/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4115 - accuracy: 0.8583 - val_loss: 0.3567 - val_accuracy: 0.8750
# Epoch 25/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3846 - accuracy: 0.8628 - val_loss: 0.4444 - val_accuracy: 0.8442
# Epoch 26/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.4100 - accuracy: 0.8553 - val_loss: 0.5197 - val_accuracy: 0.8242
# Epoch 27/100
# 600/600 [==============================] - 28s 46ms/step - loss: 0.3819 - accuracy: 0.8611 - val_loss: 0.3781 - val_accuracy: 0.8646
# Epoch 28/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3813 - accuracy: 0.8628 - val_loss: 0.5332 - val_accuracy: 0.8210
# Epoch 29/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3701 - accuracy: 0.8686 - val_loss: 0.3705 - val_accuracy: 0.8733
# Epoch 30/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3812 - accuracy: 0.8680 - val_loss: 0.4241 - val_accuracy: 0.8550
# Epoch 31/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3643 - accuracy: 0.8707 - val_loss: 0.3817 - val_accuracy: 0.8719
# Epoch 32/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.3478 - accuracy: 0.8813 - val_loss: 0.3776 - val_accuracy: 0.8712
# Epoch 33/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3630 - accuracy: 0.8712 - val_loss: 0.5062 - val_accuracy: 0.8354
# Epoch 34/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3681 - accuracy: 0.8687 - val_loss: 0.4071 - val_accuracy: 0.8573
# Epoch 35/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3408 - accuracy: 0.8819 - val_loss: 0.4548 - val_accuracy: 0.8462
# Epoch 36/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3521 - accuracy: 0.8743 - val_loss: 0.4742 - val_accuracy: 0.8454
# Epoch 37/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3438 - accuracy: 0.8783 - val_loss: 0.5160 - val_accuracy: 0.8356
# Epoch 38/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3797 - accuracy: 0.8689 - val_loss: 0.3431 - val_accuracy: 0.8844
# Epoch 39/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3474 - accuracy: 0.8803 - val_loss: 0.3591 - val_accuracy: 0.8775
# Epoch 40/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.3393 - accuracy: 0.8813 - val_loss: 0.3771 - val_accuracy: 0.8758
# Epoch 41/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3391 - accuracy: 0.8813 - val_loss: 0.3147 - val_accuracy: 0.8985
# Epoch 42/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3350 - accuracy: 0.8850 - val_loss: 0.3908 - val_accuracy: 0.8646
# Epoch 43/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3233 - accuracy: 0.8839 - val_loss: 0.3552 - val_accuracy: 0.8869
# Epoch 44/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3308 - accuracy: 0.8859 - val_loss: 0.3130 - val_accuracy: 0.8933
# Epoch 45/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3403 - accuracy: 0.8806 - val_loss: 0.3882 - val_accuracy: 0.8708
# Epoch 46/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3210 - accuracy: 0.8883 - val_loss: 0.4834 - val_accuracy: 0.8440
# Epoch 47/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3407 - accuracy: 0.8834 - val_loss: 0.3716 - val_accuracy: 0.8758
# Epoch 48/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3304 - accuracy: 0.8803 - val_loss: 0.4048 - val_accuracy: 0.8610
# Epoch 49/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3388 - accuracy: 0.8783 - val_loss: 0.3170 - val_accuracy: 0.9002
# Epoch 50/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3395 - accuracy: 0.8833 - val_loss: 0.3732 - val_accuracy: 0.8798
# Epoch 51/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3222 - accuracy: 0.8894 - val_loss: 0.3371 - val_accuracy: 0.8865
# Epoch 52/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3151 - accuracy: 0.8917 - val_loss: 0.2875 - val_accuracy: 0.9050
# Epoch 53/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3154 - accuracy: 0.8908 - val_loss: 0.2726 - val_accuracy: 0.9094
# Epoch 54/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3045 - accuracy: 0.8932 - val_loss: 0.3955 - val_accuracy: 0.8723
# Epoch 55/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3177 - accuracy: 0.8875 - val_loss: 0.4035 - val_accuracy: 0.8681
# Epoch 56/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3165 - accuracy: 0.8890 - val_loss: 0.3589 - val_accuracy: 0.8910
# Epoch 57/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3278 - accuracy: 0.8860 - val_loss: 0.3932 - val_accuracy: 0.8717
# Epoch 58/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3272 - accuracy: 0.8847 - val_loss: 0.2937 - val_accuracy: 0.9004
# Epoch 59/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3052 - accuracy: 0.8941 - val_loss: 0.2866 - val_accuracy: 0.9006
# Epoch 60/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2981 - accuracy: 0.8973 - val_loss: 0.5668 - val_accuracy: 0.8233
# Epoch 61/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3271 - accuracy: 0.8855 - val_loss: 0.3338 - val_accuracy: 0.8892
# Epoch 62/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3291 - accuracy: 0.8881 - val_loss: 0.4440 - val_accuracy: 0.8675
# Epoch 63/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3160 - accuracy: 0.8892 - val_loss: 0.3979 - val_accuracy: 0.8717
# Epoch 64/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3251 - accuracy: 0.8868 - val_loss: 0.3046 - val_accuracy: 0.9029
# Epoch 65/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2954 - accuracy: 0.8988 - val_loss: 0.3002 - val_accuracy: 0.9073
# Epoch 66/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3164 - accuracy: 0.8885 - val_loss: 0.5472 - val_accuracy: 0.8592
# Epoch 67/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3257 - accuracy: 0.8899 - val_loss: 0.3388 - val_accuracy: 0.8900
# Epoch 68/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2903 - accuracy: 0.8972 - val_loss: 0.3241 - val_accuracy: 0.9015
# Epoch 69/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3240 - accuracy: 0.8888 - val_loss: 0.3726 - val_accuracy: 0.8717
# Epoch 70/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3071 - accuracy: 0.8959 - val_loss: 0.2568 - val_accuracy: 0.9152
# Epoch 71/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3020 - accuracy: 0.8980 - val_loss: 0.3450 - val_accuracy: 0.8877
# Epoch 72/100
# 600/600 [==============================] - 28s 47ms/step - loss: 0.3140 - accuracy: 0.8918 - val_loss: 0.3982 - val_accuracy: 0.8725
# Epoch 73/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3045 - accuracy: 0.8938 - val_loss: 0.4591 - val_accuracy: 0.8585
# Epoch 74/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3191 - accuracy: 0.8906 - val_loss: 0.3909 - val_accuracy: 0.8781
# Epoch 75/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3099 - accuracy: 0.8906 - val_loss: 0.3574 - val_accuracy: 0.8835
# Epoch 76/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2873 - accuracy: 0.9000 - val_loss: 0.3580 - val_accuracy: 0.8821
# Epoch 77/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2926 - accuracy: 0.8999 - val_loss: 0.5661 - val_accuracy: 0.8410
# Epoch 78/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2867 - accuracy: 0.9015 - val_loss: 0.3534 - val_accuracy: 0.8860
# Epoch 79/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2896 - accuracy: 0.9006 - val_loss: 0.2934 - val_accuracy: 0.9071
# Epoch 80/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2791 - accuracy: 0.9034 - val_loss: 0.2908 - val_accuracy: 0.9090
# Epoch 81/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3148 - accuracy: 0.8888 - val_loss: 0.5729 - val_accuracy: 0.8242
# Epoch 82/100
# 600/600 [==============================] - 26s 43ms/step - loss: 0.3103 - accuracy: 0.8950 - val_loss: 0.4087 - val_accuracy: 0.8775
# Epoch 83/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2935 - accuracy: 0.9010 - val_loss: 0.2913 - val_accuracy: 0.9054
# Epoch 84/100
# 600/600 [==============================] - 26s 43ms/step - loss: 0.2646 - accuracy: 0.9048 - val_loss: 0.3526 - val_accuracy: 0.8896
# Epoch 85/100
# 600/600 [==============================] - 26s 42ms/step - loss: 0.3009 - accuracy: 0.8972 - val_loss: 0.3286 - val_accuracy: 0.8933
# Epoch 86/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.3024 - accuracy: 0.8996 - val_loss: 0.3536 - val_accuracy: 0.8867
# Epoch 87/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2830 - accuracy: 0.9047 - val_loss: 0.3676 - val_accuracy: 0.8842
# Epoch 88/100
# 600/600 [==============================] - 24s 41ms/step - loss: 0.3083 - accuracy: 0.8920 - val_loss: 0.4411 - val_accuracy: 0.8690
# Epoch 89/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2816 - accuracy: 0.9011 - val_loss: 0.3365 - val_accuracy: 0.8908
# Epoch 90/100
# 600/600 [==============================] - 24s 40ms/step - loss: 0.3042 - accuracy: 0.8927 - val_loss: 0.2914 - val_accuracy: 0.9062
# Epoch 91/100
# 600/600 [==============================] - 24s 40ms/step - loss: 0.2837 - accuracy: 0.8990 - val_loss: 0.4645 - val_accuracy: 0.8656
# Epoch 92/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2889 - accuracy: 0.8994 - val_loss: 0.2885 - val_accuracy: 0.9025
# Epoch 93/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.3064 - accuracy: 0.8915 - val_loss: 0.3787 - val_accuracy: 0.8781
# Epoch 94/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2740 - accuracy: 0.9068 - val_loss: 0.3001 - val_accuracy: 0.8994
# Epoch 95/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2958 - accuracy: 0.9037 - val_loss: 0.3039 - val_accuracy: 0.9040
# Epoch 96/100
# 600/600 [==============================] - 24s 41ms/step - loss: 0.3005 - accuracy: 0.8976 - val_loss: 0.3877 - val_accuracy: 0.8752
# Epoch 97/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2935 - accuracy: 0.8999 - val_loss: 0.2759 - val_accuracy: 0.9110
# Epoch 98/100
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2859 - accuracy: 0.9003 - val_loss: 0.3741 - val_accuracy: 0.8833
# Epoch 99/100
# 600/600 [==============================] - 26s 43ms/step - loss: 0.2863 - accuracy: 0.9006 - val_loss: 0.3200 - val_accuracy: 0.8931
# Epoch 100/100
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2923 - accuracy: 0.8995 - val_loss: 0.4087 - val_accuracy: 0.8742
# Execution Time:  2513.4877297699995
